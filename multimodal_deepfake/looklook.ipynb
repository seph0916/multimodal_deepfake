# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.load('/data1/josephlee/multimodal/asd.npz')
# 불러온 데이터 확인
second_item = data['first']
# 데이터 플롯
plt.figure(figsize=(10, 6))
plt.imshow(second_item, aspect='auto', origin='lower', cmap='viridis')
plt.colorbar(label='Amplitude')
plt.title('First item from batch')
plt.xlabel('Time')
plt.ylabel('Sample index')
plt.show()
